# %% [markdown]
# <a href="https://colab.research.google.com/github/JovannyReb/etch-a-sketch/blob/main/xlm_csv_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Handle the xml_data
# !unzip -q xml_data.zip

# %%
# !unzip -q respondant_xml.zip

# %%
import os
import glob
import xml.etree.ElementTree as ET
import pandas as pd

# Define source and target folders
xml_folder = 'xml_data'
csv_folder = 'truth_data'

# Ensure the output folder exists
os.makedirs(csv_folder, exist_ok=True)

# Process each XML file
for xml_path in glob.glob(os.path.join(xml_folder, '*.xml')):
    records = []

    # Parse XML
    tree = ET.parse(xml_path)
    root = tree.getroot()

    doc_source = root.findtext('docSource')

    for dt in root.findall('docTypeList/docType'):
        type_id = dt.findtext('typeId')
        for pg in dt.findall('pages/page'):
            page_no_text = pg.findtext('pageNo')
            try:
                page_no = int(page_no_text) if page_no_text else None
            except ValueError:
                page_no = None
            records.append({
                'docSource': doc_source,
                'typeId': type_id,
                'pageNo': page_no
            })

    # Build DataFrame and sort
    df = pd.DataFrame(records)
    df = df.sort_values(by='pageNo')
    # The hash map (dictionary) for the lookup

    # The hash map (dictionary) for the lookup
    doc_type_map = {
        'ABEY1': '29 (DOC-ABEYAG)',
        'BILL-MED': '03 (BILL-MED)',
        'COURT-DOC': '47 (COURT-DOC)',
        'COVERLETTER': '999 (COVERSHEET)',
        'DOC-AFF': '14 (DOC-AFF)',
        'DOC-ASN': '05 (DOC-ASN)',
        'DOC-BRIEFS': '01 (DOC-BRIEFS)',
        'DOC-CTORD': '31 (DOC-CTORD)',
        'DOC-EVD': '18 (DOC-EVD)',
        'DOC-INSPOL': '15 (DOC-INSPOL)',
        'DOC-LIEN': '24 (DOC-LIEN)',
        'DOC-LOSS': '26 (DOC-LOSS)',
        'DOC-POLRPT': '12 (DOC-POLRPT)',
        'DOC-POM': '07 (DOC-POM)',
        'DOC-PRV': '17 (DOC-PRV)',
        'DOC-SUBP': '46 (DOC-SUBP)',
        'DOC-WRKCMP': '29 (DOC-WRKCMP)',
        'EXP-WIT': '37 (EXP-WIT)',
        'FRM-AR1': '06 (FRM-AR1)',
        'FRM-NF10': '02 (FRM-NF10)',
        'FRM-NF2': '10 (FRM-NF2)',
        'LTR-DLY': '16 (REQ-VERIFY)',
        'LTR-EUO': '11 (PEER-REV)',
        'LTR-EXTRSP': '16 (REQ-VERIFY)',
        'LTR-REP': '42 (LTR-REP)',
        'LTR-SCHREQ': '43 (LTR-SCHREQ)',
        'LTR-STLAGR': '34 (LTR-STLAGR)',
        'LTR-STLOFF': '44 (SETTLE-OFFER)',
        'LTR-WTH': '36 (LTR-WTH)',
        'Medical Fee Schedule': 'Medical Fee Schedule',
        'MED-IHC': '38 (MED-IHC)',
        'MED-NEC': '23 (MED-NEC)',
        'MED-SUP': '04 (MED-RPT-EXC)',
        'MED-TST': '09 (MED-TST)',
        'NF-MISC': '25 (NF-MISC)',
        'REQ-AMEND': '06 (FRM-AR1)',
        'RPT-IME': '11 (PEER-REV)',
        'RPT-IMERE': '04 (MED-RPT-EXC)',
        'RPT-INIT': '04 (MED-RPT-EXC)',
        'RPT-PEER': '11 (PEER-REV)',
        'RPT-PEERRE': '11 (PEER-REV)'
    }

    # 1. Calculate the values for the new column first
    truth_values = df['typeId'].map(doc_type_map)

    # 2. Find the integer location of the 'typeId' column
    typeid_location = df.columns.get_loc('typeId')

    # 3. Use insert() to add the new column to the right of 'typeId'
    df.insert(loc=typeid_location + 1, column='Truth', value=truth_values)

    # Get original file name and create CSV path
    base_name = os.path.splitext(os.path.basename(xml_path))[0]
    csv_path = os.path.join(csv_folder, base_name + '.csv')

    # Save DataFrame to CSV
    df.to_csv(csv_path, index=False)

print("All XML files have been processed and saved to:", csv_folder)
# Out:
# All XML files have been processed and saved to: truth_data

# %%
from google.colab import files
import os

folder_to_download = "truth_data" # Replace with the name of your folder

# Check if the folder exists before trying to download
if os.path.exists(folder_to_download):
    # Zip the folder first to download it as a single file
    zip_filename = f"{folder_to_download}.zip"
    # !zip -r "$zip_filename" "$folder_to_download"

    # Download the zip file
    files.download(zip_filename)

    # Optional: Remove the zip file after downloading
    # os.remove(zip_filename)
else:
    print(f"Folder '{folder_to_download}' not found.")
# Out:
#   adding: truth_data/ (stored 0%)
#   adding: truth_data/31591465.csv (deflated 90%)
#   adding: truth_data/31493590.csv (deflated 90%)
#   adding: truth_data/32219527.csv (deflated 92%)
#   adding: truth_data/31298541.csv (deflated 90%)
#   adding: truth_data/32291864.csv (deflated 91%)
#   adding: truth_data/31904349.csv (deflated 91%)
#   adding: truth_data/31704962.csv (deflated 91%)
#   adding: truth_data/32342552.csv (deflated 90%)
#   adding: truth_data/31640157.csv (deflated 91%)
#   adding: truth_data/31717013.csv (deflated 90%)
#   adding: truth_data/31355950.csv (deflated 90%)
#   adding: truth_data/32043331.csv (deflated 90%)
#   adding: truth_data/31393918.csv (deflated 91%)
#   adding: truth_data/31401508.csv (deflated 91%)
#   adding: truth_data/31355392.csv (deflated 91%)
#   adding: truth_data/32219660.csv (deflated 88%)
#   adding: truth_data/32523431.csv (deflated 91%)
#   adding: truth_data/31592685.csv (deflated 90%)
#   adding: truth_data/31288607.csv (deflated 91%)
#   adding: truth_data/31444573.csv (deflated 90%)
#   adding: truth_data/31873983.csv (deflated 90%)
#   adding: truth_data/31798235.csv (deflated 91%)
#   adding: truth_data/31153552.csv (deflated 91%)
#   adding: truth_data/31860272.csv (deflated 91%)
#   adding: truth_data/32587370.csv (deflated 91%)
#   adding: truth_data/31436855.csv (deflated 91%)
#   adding: truth_data/31665189.csv (deflated 91%)
#   adding: truth_data/31561770.csv (deflated 91%)
#   adding: truth_data/31702513.csv (deflated 91%)
#   adding: truth_data/31823784.csv (deflated 91%)
#   adding: truth_data/32184616.csv (deflated 89%)
#   adding: truth_data/32513116.csv (deflated 91%)
#   adding: truth_data/31583960.csv (deflated 91%)
#   adding: truth_data/32094544.csv (deflated 89%)
#   adding: truth_data/31748757.csv (deflated 91%)
#   adding: truth_data/32548937.csv (deflated 91%)
#   adding: truth_data/32073584.csv (deflated 92%)
#   adding: truth_data/32034764.csv (deflated 91%)
#   adding: truth_data/32417439.csv (deflated 90%)
#   adding: truth_data/31811464.csv (deflated 91%)
#   adding: truth_data/31794163.csv (deflated 90%)
#   adding: truth_data/31736487.csv (deflated 90%)
#   adding: truth_data/32425968.csv (deflated 91%)
#   adding: truth_data/32136423.csv (deflated 88%)
#   adding: truth_data/32437264.csv (deflated 91%)
#   adding: truth_data/31703009.csv (deflated 91%)
#   adding: truth_data/31906770.csv (deflated 91%)
#   adding: truth_data/31770351.csv (deflated 91%)
#   adding: truth_data/31848035.csv (deflated 88%)
#   adding: truth_data/31725834.csv (deflated 91%)
#   adding: truth_data/31967080.csv (deflated 90%)
#   adding: truth_data/31685562.csv (deflated 90%)
#   adding: truth_data/32417159.csv (deflated 91%)
#   adding: truth_data/31369584.csv (deflated 91%)
#   adding: truth_data/31272296.csv (deflated 91%)
#   adding: truth_data/31650152.csv (deflated 90%)
#   adding: truth_data/31887990.csv (deflated 92%)
#   adding: truth_data/31635355.csv (deflated 92%)
#   adding: truth_data/32419509.csv (deflated 90%)
#   adding: truth_data/31266473.csv (deflated 90%)
#   adding: truth_data/32555068.csv (deflated 92%)
#   adding: truth_data/32524266.csv (deflated 88%)
#   adding: truth_data/31590443.csv (deflated 91%)
#   adding: truth_data/32093453.csv (deflated 91%)
#   adding: truth_data/32193540.csv (deflated 87%)
#   adding: truth_data/32551101.csv (deflated 89%)
#   adding: truth_data/32100577.csv (deflated 90%)
#   adding: truth_data/31386697.csv (deflated 92%)
#   adding: truth_data/31962548.csv (deflated 89%)
#   adding: truth_data/32603883.csv (deflated 91%)
#   adding: truth_data/31944369.csv (deflated 91%)
#   adding: truth_data/31988459.csv (deflated 90%)
#   adding: truth_data/31542637.csv (deflated 90%)
#   adding: truth_data/31901645.csv (deflated 91%)
#   adding: truth_data/32195473.csv (deflated 89%)
#   adding: truth_data/32427669.csv (deflated 90%)
#   adding: truth_data/32283119.csv (deflated 91%)
#   adding: truth_data/32226510.csv (deflated 90%)
#   adding: truth_data/32353887.csv (deflated 89%)
#   adding: truth_data/32341001.csv (deflated 88%)
#   adding: truth_data/31497809.csv (deflated 91%)
#   adding: truth_data/32503262.csv (deflated 90%)
#   adding: truth_data/31892430.csv (deflated 90%)
#   adding: truth_data/32499775.csv (deflated 91%)
#   adding: truth_data/32057728.csv (deflated 91%)
#   adding: truth_data/32257778.csv (deflated 91%)
#   adding: truth_data/31259210.csv (deflated 87%)
#   adding: truth_data/31809046.csv (deflated 89%)
#   adding: truth_data/31847730.csv (deflated 89%)
#   adding: truth_data/32454513.csv (deflated 90%)
#   adding: truth_data/31733638.csv (deflated 90%)
#   adding: truth_data/31897405.csv (deflated 91%)
#   adding: truth_data/31168716.csv (deflated 89%)
#   adding: truth_data/32312864.csv (deflated 91%)
#   adding: truth_data/32295561.csv (deflated 91%)
#   adding: truth_data/32131066.csv (deflated 90%)
#   adding: truth_data/32427474.csv (deflated 90%)
#   adding: truth_data/31797409.csv (deflated 89%)
#   adding: truth_data/31328508.csv (deflated 87%)
#   adding: truth_data/31948140.csv (deflated 91%)
#   adding: truth_data/31292497.csv (deflated 91%)
#   adding: truth_data/31427902.csv (deflated 90%)
#   adding: truth_data/31904610.csv (deflated 91%)
#   adding: truth_data/31498755.csv (deflated 90%)
#   adding: truth_data/31802467.csv (deflated 89%)
#   adding: truth_data/31523364.csv (deflated 91%)
#   adding: truth_data/31493622.csv (deflated 90%)
#   adding: truth_data/32072405.csv (deflated 91%)
#   adding: truth_data/31937541.csv (deflated 88%)
#   adding: truth_data/31426136.csv (deflated 90%)
#   adding: truth_data/32214583.csv (deflated 91%)
#   adding: truth_data/31629289.csv (deflated 91%)
#   adding: truth_data/31672423.csv (deflated 91%)
#   adding: truth_data/32354385.csv (deflated 90%)
#   adding: truth_data/31748393.csv (deflated 88%)
#   adding: truth_data/32559924.csv (deflated 91%)
#   adding: truth_data/32603751.csv (deflated 91%)
#   adding: truth_data/31768977.csv (deflated 92%)
#   adding: truth_data/32155618.csv (deflated 90%)
#   adding: truth_data/31726088.csv (deflated 89%)
#   adding: truth_data/31747489.csv (deflated 91%)
#   adding: truth_data/32523500.csv (deflated 90%)
#   adding: truth_data/31279168.csv (deflated 89%)
#   adding: truth_data/32194454.csv (deflated 91%)
#   adding: truth_data/31412369.csv (deflated 90%)
#   adding: truth_data/31364466.csv (deflated 92%)
#   adding: truth_data/32313532.csv (deflated 91%)
#   adding: truth_data/32473598.csv (deflated 90%)
#   adding: truth_data/31603264.csv (deflated 91%)
#   adding: truth_data/31252283.csv (deflated 90%)
#   adding: truth_data/32384517.csv (deflated 89%)
#   adding: truth_data/32086719.csv (deflated 91%)
#   adding: truth_data/31795179.csv (deflated 89%)
#   adding: truth_data/31470668.csv (deflated 91%)
#   adding: truth_data/31817875.csv (deflated 91%)
#   adding: truth_data/31790829.csv (deflated 88%)
#   adding: truth_data/32578892.csv (deflated 90%)
#   adding: truth_data/31244918.csv (deflated 89%)
#   adding: truth_data/32411263.csv (deflated 90%)
#   adding: truth_data/31316857.csv (deflated 90%)
#   adding: truth_data/32118851.csv (deflated 91%)
#   adding: truth_data/32312150.csv (deflated 91%)
#   adding: truth_data/32496656.csv (deflated 91%)
#   adding: truth_data/32277029.csv (deflated 90%)
#   adding: truth_data/31819363.csv (deflated 91%)
#   adding: truth_data/31564412.csv (deflated 90%)
#   adding: truth_data/31560678.csv (deflated 89%)
#   adding: truth_data/31782011.csv (deflated 90%)
#   adding: truth_data/32440760.csv (deflated 93%)
#   adding: truth_data/31462733.csv (deflated 91%)
#   adding: truth_data/32340948.csv (deflated 89%)
#   adding: truth_data/32361540.csv (deflated 89%)
#   adding: truth_data/31696060.csv (deflated 90%)
#   adding: truth_data/31737841.csv (deflated 91%)
#   adding: truth_data/31431542.csv (deflated 91%)
#   adding: truth_data/31176489.csv (deflated 91%)
#   adding: truth_data/32163610.csv (deflated 90%)
#   adding: truth_data/31467452.csv (deflated 90%)
#   adding: truth_data/31720371.csv (deflated 88%)
#   adding: truth_data/31720023.csv (deflated 90%)
#   adding: truth_data/31629276.csv (deflated 91%)
#   adding: truth_data/32119552.csv (deflated 91%)
#   adding: truth_data/31365753.csv (deflated 91%)
#   adding: truth_data/31875788.csv (deflated 91%)
#   adding: truth_data/31222850.csv (deflated 90%)
#   adding: truth_data/31842891.csv (deflated 91%)
#   adding: truth_data/32534457.csv (deflated 90%)
#   adding: truth_data/32372915.csv (deflated 91%)
#   adding: truth_data/31574818.csv (deflated 89%)
#   adding: truth_data/32086725.csv (deflated 91%)
#   adding: truth_data/32426746.csv (deflated 89%)
#   adding: truth_data/32580836.csv (deflated 91%)
#   adding: truth_data/31589325.csv (deflated 87%)
#   adding: truth_data/31495297.csv (deflated 91%)
#   adding: truth_data/31667718.csv (deflated 90%)
#   adding: truth_data/31788902.csv (deflated 91%)
#   adding: truth_data/31713132.csv (deflated 91%)
#   adding: truth_data/32362309.csv (deflated 90%)
#   adding: truth_data/32064102.csv (deflated 91%)
#   adding: truth_data/31542969.csv (deflated 89%)
#   adding: truth_data/31702838.csv (deflated 91%)
#   adding: truth_data/31761873.csv (deflated 90%)
#   adding: truth_data/31856458.csv (deflated 91%)
#   adding: truth_data/32532178.csv (deflated 91%)
#   adding: truth_data/32479453.csv (deflated 91%)
#   adding: truth_data/31308286.csv (deflated 90%)
#   adding: truth_data/31926922.csv (deflated 91%)
#   adding: truth_data/32244499.csv (deflated 89%)
#   adding: truth_data/32522099.csv (deflated 92%)
#   adding: truth_data/31532004.csv (deflated 91%)
#   adding: truth_data/31765784.csv (deflated 92%)
#   adding: truth_data/31745645.csv (deflated 86%)
#   adding: truth_data/31585682.csv (deflated 91%)
#   adding: truth_data/32140655.csv (deflated 89%)
#   adding: truth_data/32106235.csv (deflated 90%)
#   adding: truth_data/31424195.csv (deflated 87%)
#   adding: truth_data/32408278.csv (deflated 90%)
#   adding: truth_data/31328523.csv (deflated 89%)
#   adding: truth_data/32560000.csv (deflated 91%)
#   adding: truth_data/31945732.csv (deflated 89%)
#   adding: truth_data/31750262.csv (deflated 90%)
#   adding: truth_data/31423151.csv (deflated 91%)
#   adding: truth_data/32246804.csv (deflated 90%)
#   adding: truth_data/32195257.csv (deflated 89%)
#   adding: truth_data/32427702.csv (deflated 89%)
#   adding: truth_data/32278158.csv (deflated 90%)
#   adding: truth_data/32578153.csv (deflated 91%)
#   adding: truth_data/32524475.csv (deflated 90%)
#   adding: truth_data/31721771.csv (deflated 88%)
#   adding: truth_data/32510244.csv (deflated 91%)
#   adding: truth_data/32519188.csv (deflated 91%)
#   adding: truth_data/31668233.csv (deflated 91%)
#   adding: truth_data/31782448.csv (deflated 89%)
#   adding: truth_data/31374453.csv (deflated 91%)
#   adding: truth_data/32001261.csv (deflated 90%)
#   adding: truth_data/31247800.csv (deflated 90%)
#   adding: truth_data/31194470.csv (deflated 91%)
#   adding: truth_data/31461761.csv (deflated 91%)
#   adding: truth_data/32223766.csv (deflated 91%)
#   adding: truth_data/31495974.csv (deflated 90%)
